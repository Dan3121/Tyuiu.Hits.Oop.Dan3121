// %% [markdown]
// **Проект для управления растениями**

// %% [markdown]
// **Спринт ревью #0**

// %%
using System;
using System.Collections.Generic;
using System.Linq;

public class Plant
{
    public string Name { get; }
    public string Type { get; }
    public float High { get; }
}

public class Flower
{
    public string Color { get; }
    public int Lepestki_count { get; }
}

public class Tree
{
    public int Age { get; }
    public string List_type { get; }
}
