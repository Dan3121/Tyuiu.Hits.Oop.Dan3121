# %%
using System;
using System.Collections.Generic;

public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set { price = value; }
    }

    public int Quantity
    {
        get { return quantity; }
        set { quantity = value; }
    }

    public string Category
    {
        get { return category; }
        set { category = value; }
    }

    public string Description
    {
        get { return description; }
        set { description = value; }
    }

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int value)
    {
        quantity += value;
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}, Цена: {price:C}, Количество: {quantity}, Категория: {category}, Описание: {description}";
    }
}

public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;

    private List<Product> assignedProducts = new List<Product>();

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value; }
    }
    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        if (product != null && !assignedProducts.Contains(product))
        {
            assignedProducts.Add(product);
        }
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product != null)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($"Продано {quantity} единиц товара '{product.Name}' продавцом {name}.");
        }
        else
        {
            Console.WriteLine($"Ошибка продажи: Недостаточно товара или товар не назначен продавцу {name}.");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}, ID: {employeeId}, Зарплата: {salary:C}, Контактная информация: {contactInfo}";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;

    private List<Seller> sellers = new List<Seller>();
    private List<Product> products = new List<Product>();

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public string StoreHours
    {
        get { return storeHours; }
        set { storeHours = value; }
    }

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        if (seller != null && !sellers.Contains(seller))
        {
            sellers.Add(seller);
        }
    }

    public void ListProducts()
    {
        Console.WriteLine($"Список товаров в магазине '{storeName}':");
        if (products.Count == 0)
        {
            Console.WriteLine("Нет доступных товаров.");
        }
        else
        {
            foreach (var product in products)
            {
                Console.WriteLine(product.GetProductInfo());
            }
        }
    }

    public void AddProduct(Product product)
    {
        if (product != null && !products.Contains(product))
        {
            products.Add(product);
        }
    }

    public string GetStoreInfo()
    {
        return $"Название магазина: {storeName}, Расположения: {location}, Часы: {storeHours}";
    }
}

Product laptop = new Product("Ноутбук", 1500.00m, 10, "Электроника", "Высокопроизводительный ноутбук с 16GB RAM и SSD.");
Seller seller1 = new Seller("Иван Иванов", "EMP001", 3000.00m, "ivan@example.com");
Store store = new Store("TechStore", "ул. Технологий, 10", "9:00 - 21:00");
store.AddProduct(laptop);
store.AddSeller(seller1); 
seller1.AddProduct(laptop);

Console.WriteLine(store.GetStoreInfo());
Console.WriteLine(laptop.GetProductInfo());
Console.WriteLine(seller1.GetSellerInfo());

# %% [markdown]
# Название магазина: TechStore, Расположения: ул. Технологий, 10, Часы: 9:00 - 21:00
# Товар: Ноутбук, Цена: 1 500,00 ¤, Количество: 10, Категория: Электроника, Описание: Высокопроизводительный ноутбук с 16GB RAM и SSD.
# Продавец: Иван Иванов, ID: EMP001, Зарплата: 3 000,00 ¤, Контактная информация: ivan@example.com
